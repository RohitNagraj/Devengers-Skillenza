# %%
import numpy as np #needed for manipulation
import pandas as pd #needed for more cleaning.
import seaborn as sns # stastical visualization library
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('testms.csv') #This gets the data in the dataframe.
df = data.copy() # we create a copy, so that the original dataframe does not get destroyed.

# %%
df.shape #This reveals the number of rows and columns in the dataset.
# Out:
# (259, 27)

# %%
#We need to see the data
df.head()
# Out:
#    s.no            Timestamp  Age  Gender         Country state self_employed  \
# 0     1  2014-08-29 09:29:37   25    Male   United States    PA            No
# 1     2  2014-08-29 09:31:37   42    male   United States    IN            No
# 2     3  2014-08-29 09:31:49   34    male   United States    PA            No
# 3     4  2014-08-29 09:33:43   26  female   United States    OH            No
# 4     5  2014-08-29 09:35:46   35    Male  United Kingdom   NaN            No
#
#   family_history work_interfere no_employees  ...          leave  \
# 0            Yes          Often         6-25  ...  Somewhat easy
# 1            Yes      Sometimes         6-25  ...     Don't know
# 2            Yes          Often      100-500  ...      Very easy
# 3             No      Sometimes       26-100  ...     Don't know
# 4            Yes      Sometimes          1-5  ...      Very easy
#
#   mental_health_consequence phys_health_consequence     coworkers  \
# 0                        No                      No           Yes
# 1                     Maybe                      No  Some of them
# 2                        No                      No           Yes
# 3                     Maybe                      No  Some of them
# 4                       Yes                     Yes  Some of them
#
#      supervisor mental_health_interview phys_health_interview  \
# 0           Yes                   Maybe                 Maybe
# 1           Yes                      No                 Maybe
# 2           Yes                   Maybe                 Maybe
# 3            No                   Maybe                 Maybe
# 4  Some of them                      No                 Maybe
#
#   mental_vs_physical obs_consequence comments
# 0         Don't know              No      NaN
# 1         Don't know              No      NaN
# 2         Don't know              No      NaN
# 3         Don't know             Yes      NaN
# 4                Yes             Yes      NaN
#
# [5 rows x 27 columns]

# %%
#First, we need the info of total number of non empty columns.
info = df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 27 columns):
# s.no                         259 non-null int64
# Timestamp                    259 non-null object
# Age                          259 non-null int64
# Gender                       259 non-null object
# Country                      259 non-null object
# state                        144 non-null object
# self_employed                259 non-null object
# family_history               259 non-null object
# work_interfere               221 non-null object
# no_employees                 259 non-null object
# remote_work                  259 non-null object
# tech_company                 259 non-null object
# benefits                     259 non-null object
# care_options                 259 non-null object
# wellness_program             259 non-null object
# seek_help                    259 non-null object
# anonymity                    259 non-null object
# leave                        259 non-null object
# mental_health_consequence    259 non-null object
# phys_health_consequence      259 non-null object
# coworkers                    259 non-null object
# supervisor                   259 non-null object
# mental_health_interview      259 non-null object
# phys_health_interview        259 non-null object
# mental_vs_physical           259 non-null object
# obs_consequence              259 non-null object
# comments                     37 non-null object
# dtypes: int64(2), object(25)
# memory usage: 54.7+ KB

# %%
#We get the count of missing values only.
df.apply(lambda x: sum(x.isnull()))
# Out:
# s.no                           0
# Timestamp                      0
# Age                            0
# Gender                         0
# Country                        0
# state                        115
# self_employed                  0
# family_history                 0
# work_interfere                38
# no_employees                   0
# remote_work                    0
# tech_company                   0
# benefits                       0
# care_options                   0
# wellness_program               0
# seek_help                      0
# anonymity                      0
# leave                          0
# mental_health_consequence      0
# phys_health_consequence        0
# coworkers                      0
# supervisor                     0
# mental_health_interview        0
# phys_health_interview          0
# mental_vs_physical             0
# obs_consequence                0
# comments                     222
# dtype: int64

# %%
#The comments quantity is insignificant, so lets drop it.
df.drop(columns='comments',inplace=True,axis=0)

# %%
df.head()
# Out:
#    s.no            Timestamp  Age  Gender         Country state self_employed  \
# 0     1  2014-08-29 09:29:37   25    Male   United States    PA            No
# 1     2  2014-08-29 09:31:37   42    male   United States    IN            No
# 2     3  2014-08-29 09:31:49   34    male   United States    PA            No
# 3     4  2014-08-29 09:33:43   26  female   United States    OH            No
# 4     5  2014-08-29 09:35:46   35    Male  United Kingdom   NaN            No
#
#   family_history work_interfere no_employees  ...   anonymity          leave  \
# 0            Yes          Often         6-25  ...         Yes  Somewhat easy
# 1            Yes      Sometimes         6-25  ...  Don't know     Don't know
# 2            Yes          Often      100-500  ...         Yes      Very easy
# 3             No      Sometimes       26-100  ...  Don't know     Don't know
# 4            Yes      Sometimes          1-5  ...         Yes      Very easy
#
#   mental_health_consequence phys_health_consequence     coworkers  \
# 0                        No                      No           Yes
# 1                     Maybe                      No  Some of them
# 2                        No                      No           Yes
# 3                     Maybe                      No  Some of them
# 4                       Yes                     Yes  Some of them
#
#      supervisor mental_health_interview phys_health_interview  \
# 0           Yes                   Maybe                 Maybe
# 1           Yes                      No                 Maybe
# 2           Yes                   Maybe                 Maybe
# 3            No                   Maybe                 Maybe
# 4  Some of them                      No                 Maybe
#
#   mental_vs_physical obs_consequence
# 0         Don't know              No
# 1         Don't know              No
# 2         Don't know              No
# 3         Don't know             Yes
# 4                Yes             Yes
#
# [5 rows x 26 columns]

# %%
df['work_interfere'].unique()
#This tells us that, only five types of work_interfere_types exist
#Lets not keep nan as the value and replace that by a unique categfory U
df['work_interfere'] = df['work_interfere'].fillna('U')
df['work_interfere'].unique()
# Out:
# array(['Often', 'Sometimes', 'Never', 'U', 'Rarely'], dtype=object)

# %%
#Now, lets deal with the state.
country = list(df['Country'])
# print(country)
states=  list(df['state'])
# print(states)

#Lets replace all na by Other
df['state'] = df['state'].fillna('Other')
df.state.head(10)
# Out:
# 0       PA
# 1       IN
# 2       PA
# 3       OH
# 4    Other
# 5    Other
# 6       PA
# 7       SD
# 8       IN
# 9       CA
# Name: state, dtype: object

# %%
#Now, we don't have any missing values in the entire dataset, lets check once.
a = df.apply(lambda x: sum(x.isnull()))
print(a)
# Out:
# s.no                         0
# Timestamp                    0
# Age                          0
# Gender                       0
# Country                      0
# state                        0
# self_employed                0
# family_history               0
# work_interfere               0
# no_employees                 0
# remote_work                  0
# tech_company                 0
# benefits                     0
# care_options                 0
# wellness_program             0
# seek_help                    0
# anonymity                    0
# leave                        0
# mental_health_consequence    0
# phys_health_consequence      0
# coworkers                    0
# supervisor                   0
# mental_health_interview      0
# phys_health_interview        0
# mental_vs_physical           0
# obs_consequence              0
# dtype: int64

# %%
#We can take the s.no as our usual index, they will just differ by one as by default, that starts from zero.
#The timestamp data seems to be in proper format, so we have no need to alter that.

# %%
#We have all the age in proper fromat, no missing values and stuff, so age is proper.
#Gender.
df.Gender.unique()
# Out:
# array(['Male', 'male', 'female', 'm', 'M', 'F', 'Female',
#        'Female (trans)', 'f', 'Malr', 'Male ', 'p', 'Woman', 'femail',
#        'Cis Man', 'ostensibly male, unsure what that really means'],
#       dtype=object)

# %%
#Looking at the array, we see that, that, we have genders of various types,
# so we will club all reprsenting males into M and all representing females as F.
#Now, three values, "cis man","p","ostensibly male" is ambiguous, lets assign them as U.
#Have to try a better way to change, works for time being.

X = df['Gender']
for i in range(0,259):
    if(X[i][0] == 'M' or X[i][0] == 'm'):
        X[i] = 'M'
    elif (X[i][0] == 'F' or X[i][0] == 'f' or X[i][0] == 'W'):
        X[i] = 'F'
    else:
        X[i] = 'U'
df['Gender'] = X
# Out:
# /home/raghav/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /home/raghav/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/raghav/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
df['Gender'].unique()
# Out:
# array(['M', 'F', 'U'], dtype=object)

# %%
df.head(100)
# Out:
#     s.no            Timestamp  Age Gender         Country  state  \
# 0      1  2014-08-29 09:29:37   25      M   United States     PA
# 1      2  2014-08-29 09:31:37   42      M   United States     IN
# 2      3  2014-08-29 09:31:49   34      M   United States     PA
# 3      4  2014-08-29 09:33:43   26      F   United States     OH
# 4      5  2014-08-29 09:35:46   35      M  United Kingdom  Other
# 5      6  2014-08-29 09:36:04   34      M  United Kingdom  Other
# 6      7  2014-08-29 09:36:46   38      M   United States     PA
# 7      8  2014-08-29 09:40:13   34      M   United States     SD
# 8      9  2014-08-29 09:42:23   39      M   United States     IN
# 9     10  2014-08-29 09:46:56   44      F   United States     CA
# 10    11  2014-08-29 09:47:10   40      M   United States     TN
# 11    12  2014-08-29 09:47:30   33      F   United States     TX
# 12    13  2014-08-29 09:51:35   24      F   United States     TN
# 13    14  2014-08-29 09:53:38   38      F   United States     OR
# 14    15  2014-08-29 09:53:50   31      M   United States     SD
# 15    16  2014-08-29 09:54:01   23      M          Israel  Other
# 16    17  2014-08-29 09:54:11   26      F   United States     NY
# 17    18  2014-08-29 09:58:55   46      F   United States     CT
# 18    19  2014-08-29 09:59:39   30      M   United States     CA
# 19    20  2014-08-29 10:03:24   25      M   United States  Other
# 20    21  2014-08-29 10:05:57   19      M          Canada  Other
# 21    22  2014-08-29 10:06:29   30      F   United States     GA
# 22    23  2014-08-29 10:12:10   32      M   United States     TN
# 23    24  2014-08-29 10:13:39   32      M  United Kingdom  Other
# 24    25  2014-08-29 10:13:43   37      M   United States     IN
# 25    26  2014-08-29 10:16:45   42      M   United States     CA
# 26    27  2014-08-29 10:27:15   25      F   United States     OR
# 27    28  2014-08-29 10:30:09   19      M   United States     IN
# 28    29  2014-08-29 10:32:24   40      F   United States     GA
# 29    30  2014-08-29 10:33:45   34      M   United States     IN
# ..   ...                  ...  ...    ...             ...    ...
# 70    71  2014-08-29 12:54:31   39      F   United States     OH
# 71    72  2014-08-29 13:17:33   43      M   United States     OH
# 72    73  2014-08-29 13:23:40   41      M   United States     IL
# 73    74  2014-08-29 13:58:25   25      M   United States     IN
# 74    75  2014-08-29 14:04:59   31      M   United States     CA
# 75    76  2014-08-29 14:09:21   40      M   United States     WA
# 76    77  2014-08-29 14:31:00   43      M   United States     VA
# 77    78  2014-08-29 14:51:49   27      F   United States     WA
# 78    79  2014-08-29 14:59:43   37      F   United States     NJ
# 79    80  2014-08-29 15:10:39   32      M     Netherlands  Other
# 80    81  2014-08-29 15:59:55   25      M   United States     UT
# 81    82  2014-08-29 16:07:05   29      M     Netherlands  Other
# 82    83  2014-08-29 16:17:32   30      F   United States     TN
# 83    84  2014-08-29 16:21:16   34      F          Canada  Other
# 84    85  2014-08-29 16:30:50   32      M  United Kingdom  Other
# 85    86  2014-08-29 16:50:08   37      M         Germany  Other
# 86    87  2014-08-29 16:51:31   41      M         Germany  Other
# 87    88  2014-08-29 16:56:06   38      M   United States     IN
# 88    89  2014-08-29 17:04:07   32      M   United States     IN
# 89    90  2014-08-29 17:04:12   28      F   United States     CA
# 90    91  2014-08-29 17:26:15   11      M   United States     OH
# 91    92  2014-08-29 17:32:31   43      M   United States     TX
# 92    93  2014-08-29 17:35:16   32      M   United States     TN
# 93    94  2014-08-29 17:54:32   25      M   United States     WA
# 94    95  2014-08-29 18:33:32   37      M   United States     UT
# 95    96  2014-08-29 18:39:07   36      M   United States     AL
# 96    97  2014-08-29 19:32:13   24      M   United States     WI
# 97    98  2014-08-29 19:34:40   40      M   United States     WA
# 98    99  2014-08-29 20:53:09   29      M   United States     WI
# 99   100  2014-08-29 20:53:58   43      M   United States     NY
#
#    self_employed family_history work_interfere    no_employees  ...  \
# 0             No            Yes          Often            6-25  ...
# 1             No            Yes      Sometimes            6-25  ...
# 2             No            Yes          Often         100-500  ...
# 3             No             No      Sometimes          26-100  ...
# 4             No            Yes      Sometimes             1-5  ...
# 5             No             No          Never        500-1000  ...
# 6             No            Yes      Sometimes         100-500  ...
# 7             No             No      Sometimes         100-500  ...
# 8             No            Yes      Sometimes            6-25  ...
# 9             No             No              U         100-500  ...
# 10            No             No              U  More than 1000  ...
# 11           Yes             No          Never             1-5  ...
# 12            No            Yes      Sometimes  More than 1000  ...
# 13            No            Yes      Sometimes          26-100  ...
# 14            No             No      Sometimes  More than 1000  ...
# 15            No             No              U         100-500  ...
# 16            No             No              U            6-25  ...
# 17            No             No          Often  More than 1000  ...
# 18            No            Yes      Sometimes          26-100  ...
# 19            No             No         Rarely          26-100  ...
# 20            No             No          Never          26-100  ...
# 21            No            Yes      Sometimes        500-1000  ...
# 22            No             No          Never            6-25  ...
# 23            No             No              U            6-25  ...
# 24            No            Yes      Sometimes          26-100  ...
# 25            No            Yes      Sometimes            6-25  ...
# 26            No             No          Never  More than 1000  ...
# 27            No             No      Sometimes             1-5  ...
# 28            No            Yes          Never         100-500  ...
# 29            No             No              U  More than 1000  ...
# ..           ...            ...            ...             ...  ...
# 70            No             No      Sometimes            6-25  ...
# 71            No             No      Sometimes  More than 1000  ...
# 72            No             No         Rarely  More than 1000  ...
# 73            No             No          Never  More than 1000  ...
# 74            No             No      Sometimes         100-500  ...
# 75            No            Yes      Sometimes  More than 1000  ...
# 76           Yes            Yes      Sometimes             1-5  ...
# 77            No            Yes          Often  More than 1000  ...
# 78            No            Yes      Sometimes          26-100  ...
# 79           Yes             No      Sometimes             1-5  ...
# 80            No            Yes          Often             1-5  ...
# 81            No            Yes          Often             1-5  ...
# 82            No            Yes          Often  More than 1000  ...
# 83            No            Yes          Often          26-100  ...
# 84            No            Yes      Sometimes             1-5  ...
# 85            No             No              U            6-25  ...
# 86            No             No      Sometimes  More than 1000  ...
# 87            No            Yes          Never  More than 1000  ...
# 88            No             No      Sometimes          26-100  ...
# 89            No            Yes      Sometimes         100-500  ...
# 90           Yes             No          Never             1-5  ...
# 91            No            Yes          Never         100-500  ...
# 92            No            Yes          Often         100-500  ...
# 93            No             No      Sometimes  More than 1000  ...
# 94            No             No      Sometimes         100-500  ...
# 95           Yes             No      Sometimes             1-5  ...
# 96            No            Yes         Rarely            6-25  ...
# 97            No            Yes      Sometimes  More than 1000  ...
# 98            No             No              U  More than 1000  ...
# 99            No             No          Never        500-1000  ...
#
#      anonymity               leave mental_health_consequence  \
# 0          Yes       Somewhat easy                        No
# 1   Don't know          Don't know                     Maybe
# 2          Yes           Very easy                        No
# 3   Don't know          Don't know                     Maybe
# 4          Yes           Very easy                       Yes
# 5   Don't know           Very easy                     Maybe
# 6          Yes           Very easy                        No
# 7   Don't know          Don't know                       Yes
# 8          Yes       Somewhat easy                        No
# 9   Don't know          Don't know                       Yes
# 10         Yes          Don't know                     Maybe
# 11         Yes       Somewhat easy                     Maybe
# 12  Don't know  Somewhat difficult                       Yes
# 13  Don't know          Don't know                        No
# 14         Yes          Don't know                       Yes
# 15         Yes           Very easy                     Maybe
# 16  Don't know       Somewhat easy                        No
# 17  Don't know          Don't know                       Yes
# 18  Don't know          Don't know                     Maybe
# 19  Don't know       Somewhat easy                       Yes
# 20  Don't know       Somewhat easy                        No
# 21         Yes       Somewhat easy                     Maybe
# 22  Don't know       Somewhat easy                        No
# 23  Don't know          Don't know                     Maybe
# 24  Don't know       Somewhat easy                     Maybe
# 25  Don't know          Don't know                     Maybe
# 26  Don't know          Don't know                     Maybe
# 27  Don't know          Don't know                        No
# 28  Don't know          Don't know                       Yes
# 29  Don't know          Don't know                     Maybe
# ..         ...                 ...                       ...
# 70  Don't know          Don't know                     Maybe
# 71  Don't know          Don't know                     Maybe
# 72  Don't know          Don't know                     Maybe
# 73  Don't know          Don't know                        No
# 74  Don't know       Somewhat easy                     Maybe
# 75         Yes          Don't know                       Yes
# 76  Don't know          Don't know                     Maybe
# 77         Yes      Very difficult                     Maybe
# 78  Don't know          Don't know                       Yes
# 79         Yes      Very difficult                     Maybe
# 80         Yes           Very easy                     Maybe
# 81  Don't know      Very difficult                        No
# 82  Don't know  Somewhat difficult                       Yes
# 83  Don't know       Somewhat easy                        No
# 84         Yes       Somewhat easy                     Maybe
# 85         Yes           Very easy                        No
# 86  Don't know  Somewhat difficult                        No
# 87  Don't know          Don't know                       Yes
# 88         Yes          Don't know                        No
# 89  Don't know          Don't know                     Maybe
# 90         Yes           Very easy                        No
# 91  Don't know       Somewhat easy                     Maybe
# 92  Don't know      Very difficult                       Yes
# 93         Yes          Don't know                       Yes
# 94         Yes           Very easy                        No
# 95          No      Very difficult                        No
# 96  Don't know           Very easy                        No
# 97  Don't know  Somewhat difficult                     Maybe
# 98         Yes       Somewhat easy                        No
# 99  Don't know          Don't know                        No
#
#    phys_health_consequence     coworkers    supervisor  \
# 0                       No           Yes           Yes
# 1                       No  Some of them           Yes
# 2                       No           Yes           Yes
# 3                       No  Some of them            No
# 4                      Yes  Some of them  Some of them
# 5                       No           Yes           Yes
# 6                       No           Yes           Yes
# 7                       No  Some of them            No
# 8                       No  Some of them           Yes
# 9                       No            No            No
# 10                      No            No           Yes
# 11                      No            No  Some of them
# 12                   Maybe  Some of them  Some of them
# 13                      No  Some of them           Yes
# 14                   Maybe  Some of them  Some of them
# 15                      No  Some of them           Yes
# 16                      No           Yes           Yes
# 17                      No  Some of them  Some of them
# 18                      No  Some of them            No
# 19                      No  Some of them  Some of them
# 20                      No  Some of them  Some of them
# 21                   Maybe  Some of them  Some of them
# 22                      No           Yes           Yes
# 23                   Maybe            No            No
# 24                      No  Some of them  Some of them
# 25                   Maybe  Some of them  Some of them
# 26                      No  Some of them           Yes
# 27                      No  Some of them           Yes
# 28                     Yes            No            No
# 29                   Maybe  Some of them           Yes
# ..                     ...           ...           ...
# 70                   Maybe  Some of them  Some of them
# 71                      No            No            No
# 72                   Maybe  Some of them            No
# 73                      No  Some of them           Yes
# 74                      No  Some of them            No
# 75                     Yes            No            No
# 76                   Maybe  Some of them  Some of them
# 77                      No           Yes  Some of them
# 78                   Maybe            No            No
# 79                      No  Some of them           Yes
# 80                      No           Yes           Yes
# 81                   Maybe           Yes           Yes
# 82                      No            No            No
# 83                      No  Some of them  Some of them
# 84                   Maybe  Some of them  Some of them
# 85                      No           Yes           Yes
# 86                      No           Yes           Yes
# 87                   Maybe  Some of them            No
# 88                      No  Some of them           Yes
# 89                      No  Some of them  Some of them
# 90                      No  Some of them  Some of them
# 91                      No  Some of them  Some of them
# 92                      No           Yes           Yes
# 93                      No            No            No
# 94                      No            No           Yes
# 95                      No            No            No
# 96                      No           Yes           Yes
# 97                      No  Some of them  Some of them
# 98                      No  Some of them           Yes
# 99                      No           Yes  Some of them
#
#    mental_health_interview phys_health_interview mental_vs_physical  \
# 0                    Maybe                 Maybe         Don't know
# 1                       No                 Maybe         Don't know
# 2                    Maybe                 Maybe         Don't know
# 3                    Maybe                 Maybe         Don't know
# 4                       No                 Maybe                Yes
# 5                       No                    No                Yes
# 6                      Yes                   Yes         Don't know
# 7                       No                 Maybe         Don't know
# 8                    Maybe                   Yes                Yes
# 9                       No                    No         Don't know
# 10                      No                    No         Don't know
# 11                      No                    No                Yes
# 12                      No                    No                 No
# 13                      No                    No         Don't know
# 14                      No                 Maybe                Yes
# 15                   Maybe                   Yes         Don't know
# 16                      No                 Maybe                Yes
# 17                      No                    No                 No
# 18                      No                 Maybe         Don't know
# 19                      No                   Yes         Don't know
# 20                      No                 Maybe                 No
# 21                      No                    No                 No
# 22                      No                 Maybe                Yes
# 23                      No                 Maybe         Don't know
# 24                      No                 Maybe                 No
# 25                      No                    No         Don't know
# 26                   Maybe                    No                Yes
# 27                   Maybe                 Maybe         Don't know
# 28                      No                    No         Don't know
# 29                      No                    No         Don't know
# ..                     ...                   ...                ...
# 70                      No                 Maybe                 No
# 71                      No                    No         Don't know
# 72                      No                    No                Yes
# 73                      No                    No         Don't know
# 74                      No                 Maybe                 No
# 75                      No                 Maybe                 No
# 76                      No                 Maybe         Don't know
# 77                      No                 Maybe                 No
# 78                      No                 Maybe         Don't know
# 79                      No                 Maybe                 No
# 80                      No                 Maybe                 No
# 81                   Maybe                    No                Yes
# 82                      No                 Maybe                 No
# 83                      No                    No                Yes
# 84                      No                 Maybe                 No
# 85                   Maybe                 Maybe                Yes
# 86                      No                    No                Yes
# 87                      No                    No                 No
# 88                      No                 Maybe         Don't know
# 89                      No                    No                Yes
# 90                      No                 Maybe                Yes
# 91                      No                 Maybe                 No
# 92                      No                   Yes                 No
# 93                      No                    No                Yes
# 94                      No                    No                Yes
# 95                      No                    No                 No
# 96                   Maybe                   Yes                Yes
# 97                      No                 Maybe         Don't know
# 98                      No                 Maybe                Yes
# 99                      No                    No                Yes
#
#    obs_consequence
# 0               No
# 1               No
# 2               No
# 3              Yes
# 4              Yes
# 5               No
# 6               No
# 7               No
# 8               No
# 9               No
# 10              No
# 11              No
# 12             Yes
# 13              No
# 14              No
# 15              No
# 16              No
# 17             Yes
# 18              No
# 19             Yes
# 20              No
# 21             Yes
# 22              No
# 23              No
# 24              No
# 25              No
# 26              No
# 27              No
# 28              No
# 29              No
# ..             ...
# 70              No
# 71              No
# 72             Yes
# 73              No
# 74              No
# 75             Yes
# 76              No
# 77             Yes
# 78              No
# 79              No
# 80              No
# 81              No
# 82              No
# 83              No
# 84              No
# 85              No
# 86              No
# 87              No
# 88              No
# 89              No
# 90              No
# 91              No
# 92              No
# 93              No
# 94              No
# 95             Yes
# 96              No
# 97             Yes
# 98              No
# 99              No
#
# [100 rows x 26 columns]

# %%
#NOw, we have only M,F,U.

# %%
#Now, lets work on countries.
df.Country.unique()
# Out:
# array(['United States', 'United Kingdom', 'Israel', 'Canada', 'Australia',
#        'Italy', 'Brazil', 'Switzerland', 'Germany', 'South Africa',
#        'Greece', 'Netherlands', 'France', 'India', 'Croatia',
#        'New Zealand', 'Moldova', 'Sweden', 'Belgium', 'Singapore',
#        'Poland', 'Colombia', 'Georgia', 'China', 'Bulgaria', 'Ireland',
#        'Czech Republic', 'Philippines', 'Finland'], dtype=object)

# %%
#Everything is fine with Country.

# %%
df.state.head(100)
#This is also pretty fine.
# Out:
# 0        PA
# 1        IN
# 2        PA
# 3        OH
# 4     Other
# 5     Other
# 6        PA
# 7        SD
# 8        IN
# 9        CA
# 10       TN
# 11       TX
# 12       TN
# 13       OR
# 14       SD
# 15    Other
# 16       NY
# 17       CT
# 18       CA
# 19    Other
# 20    Other
# 21       GA
# 22       TN
# 23    Other
# 24       IN
# 25       CA
# 26       OR
# 27       IN
# 28       GA
# 29       IN
#       ...
# 70       OH
# 71       OH
# 72       IL
# 73       IN
# 74       CA
# 75       WA
# 76       VA
# 77       WA
# 78       NJ
# 79    Other
# 80       UT
# 81    Other
# 82       TN
# 83    Other
# 84    Other
# 85    Other
# 86    Other
# 87       IN
# 88       IN
# 89       CA
# 90       OH
# 91       TX
# 92       TN
# 93       WA
# 94       UT
# 95       AL
# 96       WI
# 97       WA
# 98       WI
# 99       NY
# Name: state, Length: 100, dtype: object

# %%
df.head(10)
# Out:
#    s.no            Timestamp  Age Gender         Country  state self_employed  \
# 0     1  2014-08-29 09:29:37   25      M   United States     PA            No
# 1     2  2014-08-29 09:31:37   42      M   United States     IN            No
# 2     3  2014-08-29 09:31:49   34      M   United States     PA            No
# 3     4  2014-08-29 09:33:43   26      F   United States     OH            No
# 4     5  2014-08-29 09:35:46   35      M  United Kingdom  Other            No
# 5     6  2014-08-29 09:36:04   34      M  United Kingdom  Other            No
# 6     7  2014-08-29 09:36:46   38      M   United States     PA            No
# 7     8  2014-08-29 09:40:13   34      M   United States     SD            No
# 8     9  2014-08-29 09:42:23   39      M   United States     IN            No
# 9    10  2014-08-29 09:46:56   44      F   United States     CA            No
#
#   family_history work_interfere no_employees  ...   anonymity          leave  \
# 0            Yes          Often         6-25  ...         Yes  Somewhat easy
# 1            Yes      Sometimes         6-25  ...  Don't know     Don't know
# 2            Yes          Often      100-500  ...         Yes      Very easy
# 3             No      Sometimes       26-100  ...  Don't know     Don't know
# 4            Yes      Sometimes          1-5  ...         Yes      Very easy
# 5             No          Never     500-1000  ...  Don't know      Very easy
# 6            Yes      Sometimes      100-500  ...         Yes      Very easy
# 7             No      Sometimes      100-500  ...  Don't know     Don't know
# 8            Yes      Sometimes         6-25  ...         Yes  Somewhat easy
# 9             No              U      100-500  ...  Don't know     Don't know
#
#   mental_health_consequence phys_health_consequence     coworkers  \
# 0                        No                      No           Yes
# 1                     Maybe                      No  Some of them
# 2                        No                      No           Yes
# 3                     Maybe                      No  Some of them
# 4                       Yes                     Yes  Some of them
# 5                     Maybe                      No           Yes
# 6                        No                      No           Yes
# 7                       Yes                      No  Some of them
# 8                        No                      No  Some of them
# 9                       Yes                      No            No
#
#      supervisor mental_health_interview phys_health_interview  \
# 0           Yes                   Maybe                 Maybe
# 1           Yes                      No                 Maybe
# 2           Yes                   Maybe                 Maybe
# 3            No                   Maybe                 Maybe
# 4  Some of them                      No                 Maybe
# 5           Yes                      No                    No
# 6           Yes                     Yes                   Yes
# 7            No                      No                 Maybe
# 8           Yes                   Maybe                   Yes
# 9            No                      No                    No
#
#   mental_vs_physical obs_consequence
# 0         Don't know              No
# 1         Don't know              No
# 2         Don't know              No
# 3         Don't know             Yes
# 4                Yes             Yes
# 5                Yes              No
# 6         Don't know              No
# 7         Don't know              No
# 8                Yes              No
# 9         Don't know              No
#
# [10 rows x 26 columns]

# %%
#Lets look at type of values of self employed
df.self_employed.unique() 
#This is a perfect one with No and Yes.
# self_employed = {'Yes':0,'No':1}
# df.self_employed = [self_employed[item] for item in df.self_employed]
# df.self_employed.unique()
# Out:
# array([1, 0])

# %%
df.family_history.unique()
family_history = {'Yes':0,'No':1}
df.family_history = [family_history[item] for item in df.family_history]
df.self_employed.unique()
#Even this is awesome.
# Out:
# array([1, 0])

# %%
df.work_interfere.unique()
#Even, these are perfect 5 categories.
work_interfere = {'Often':0,'Sometimes':1,'Never':2,'U':3,'Rarely':4}
df.work_interfere = [work_interfere[item] for item in df.work_interfere]
df.work_interfere.unique()
# Out:
# array([0, 1, 2, 3, 4])

# %%
#Now, we have to look at the number of employees.
df.no_employees.unique()
#These ranges look fine, can be clubbed together, but that depends on the model used, clubbing mkisgt be useful in visualizations.
# Out:
# array(['6-25', '100-500', '26-100', '1-5', '500-1000', 'More than 1000'],
#       dtype=object)

# %%
df.anonymity.unique()
anonymity = {'Yes':0,'No':1,"Don't know":2}
df.anonymity = [anonymity[item] for item in df.anonymity]
df.anonymity.unique()
#Perfect as well.
# Out:
# array([0, 2, 1])

# %%
df.leave.unique()
leave = {'Somewhat easy':0, "Don't know":1, 'Very easy':2, 'Somewhat difficult':3,'Very difficult':4}
df.leave = [leave[item] for item in df.leave]
df.leave.unique()
#These are the 5 categories, can be clubbed according to the model.
# Out:
# array([0, 1, 2, 3, 4])

# %%
df.mental_health_consequence.unique()
mental_health_consequence = {'Yes':0, "No":1, 'Maybe':2}
df.mental_health_consequence = [mental_health_consequence[item] for item in df.mental_health_consequence]
df.mental_health_consequence.unique()
#This is also super perfect
# Out:
# array([1, 2, 0])

# %%
df.coworkers.unique()
coworkers = {'Yes':0, 'Some of them':2, 'No':1}
df.coworkers = [coworkers[item] for item in df.coworkers]
df.coworkers.unique()
#Seems fine
# Out:
# array([0, 2, 1])

# %%
df.supervisor.unique()
supervisor = {'Yes':0, 'Some of them':2, 'No':1}
df.supervisor = [supervisor[item] for item in df.supervisor]
df.supervisor.unique()
# Out:
# array([0, 1, 2])

# %%
df.mental_health_interview.unique()

mental_health_interview = {'Yes':0, "No":1, 'Maybe':2}
df.mental_health_interview = [mental_health_interview[item] for item in df.mental_health_interview]
df.mental_health_interview.unique()
#This is perfect
# Out:
# array([2, 1, 0])

# %%
df.phys_health_interview.unique()

phys_health_interview = {'Yes':0, "No":1, 'Maybe':2}
df.phys_health_interview = [phys_health_interview[item] for item in df.phys_health_interview]
df.phys_health_interview.unique()
#This is perfect.
# Out:
# array([2, 1, 0])

# %%
df.mental_vs_physical.unique()

mental_vs_physical= {'Yes':0,'No':1,"Don't know":2}
df.mental_vs_physical = [mental_vs_physical[item] for item in df.mental_vs_physical]
df.mental_vs_physical.unique()
#This is perfect as well.
# Out:
# array([2, 0, 1])

# %%
df.obs_consequence.unique()
obs_consequence = {'Yes':0,'No':1,"Don't know":2}
df.obs_consequence = [obs_consequence[item] for item in df.obs_consequence]
df.obs_consequence.unique()
#Fine as well.
# Out:
# array([1, 0])

# %%
df.head(5)
# Out:
#    Age Gender         Country  self_employed  family_history  work_interfere  \
# 0   25      M   United States              1               0               0
# 1   42      M   United States              1               0               1
# 2   34      M   United States              1               0               0
# 3   26      F   United States              1               1               1
# 4   35      M  United Kingdom              1               0               1
#
#   no_employees remote_work tech_company    benefits  ... supervisor  \
# 0         6-25         Yes          Yes         Yes  ...          0
# 1         6-25         Yes          Yes  Don't know  ...          0
# 2      100-500          No          Yes         Yes  ...          0
# 3       26-100         Yes          Yes  Don't know  ...          1
# 4          1-5          No          Yes          No  ...          2
#
#   mental_health_interview phys_health_interview  mental_vs_physical  \
# 0                       2                     2                   2
# 1                       1                     2                   2
# 2                       2                     2                   2
# 3                       2                     2                   2
# 4                       1                     2                   0
#
#    obs_consequence  start_range end_range  Day  Month  Year
# 0                1            6        25   29      8  2014
# 1                1            6        25   29      8  2014
# 2                1          100       500   29      8  2014
# 3                0           26       100   29      8  2014
# 4                0            1         5   29      8  2014
#
# [5 rows x 28 columns]

# %%
def func(x):
    if len(x.split("-")) != 1:
        return x.split("-")[1]
    else:
        return ""
a = df['no_employees'].apply(lambda x: x.split("-")[0])
b = df['no_employees'].apply(func)

# %%
df['start_range'] = a
df['end_range'] = b

#Guys, i don't know machine learning, this is my assumption, so i put it.

def func2(x):
    if x == "":
        return 10000
    else:
        return x

#I added these two columns becuase the values might be needed as parameters(integer) in the ML model.
#Now, the values with more than thousand has end_range as null, so lets add that as 10000 and convert the types as integer.
df['end_range']=df['end_range'].apply(func2)

# %%
def func3(x):
    if x[0] == "M":
        return "1000"
    else:
        return x
df['start_range']=df['start_range'].apply(func3)

# %%
df['start_range'] = pd.to_numeric(df['start_range'])

# %%
df['end_range'] = pd.to_numeric(df['end_range'])

# %%
#There are no null values and hence the data is clean now.

# %%
df['Year'] = pd.to_numeric(df['Year'])
df['Month'] = pd.to_numeric(df['Month'])
df['Day'] = pd.to_numeric(df['Day'])

# %%
df.head()
# Out:
#    Age Gender         Country  self_employed  family_history  work_interfere  \
# 0   25      M   United States              1               0               0
# 1   42      M   United States              1               0               1
# 2   34      M   United States              1               0               0
# 3   26      F   United States              1               1               1
# 4   35      M  United Kingdom              1               0               1
#
#   no_employees remote_work tech_company    benefits  ... supervisor  \
# 0         6-25         Yes          Yes         Yes  ...          0
# 1         6-25         Yes          Yes  Don't know  ...          0
# 2      100-500          No          Yes         Yes  ...          0
# 3       26-100         Yes          Yes  Don't know  ...          1
# 4          1-5          No          Yes          No  ...          2
#
#   mental_health_interview phys_health_interview  mental_vs_physical  \
# 0                       2                     2                   2
# 1                       1                     2                   2
# 2                       2                     2                   2
# 3                       2                     2                   2
# 4                       1                     2                   0
#
#    obs_consequence  start_range end_range  Day  Month  Year
# 0                1            6        25   29      8  2014
# 1                1            6        25   29      8  2014
# 2                1          100       500   29      8  2014
# 3                0           26       100   29      8  2014
# 4                0            1         5   29      8  2014
#
# [5 rows x 28 columns]

# %%
df.remote_work.unique()
remote_work = {'Yes':0,'No':1}
df.remote_work = [remote_work[item] for item in df.remote_work]
df.remote_work.unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-0cdcc17064f6> in <module>
#       1 df.remote_work.unique()
#       2 remote_work = {'Yes':0,'No':1}
# ----> 3 df.remote_work = [remote_work[item] for item in df.remote_work]
#       4 df.remote_work.unique()
#
# <ipython-input-76-0cdcc17064f6> in <listcomp>(.0)
#       1 df.remote_work.unique()
#       2 remote_work = {'Yes':0,'No':1}
# ----> 3 df.remote_work = [remote_work[item] for item in df.remote_work]
#       4 df.remote_work.unique()
#
# KeyError: 0

# %%
df.tech_company.unique()
tech_company = {'Yes':0,'No':1}
df.tech_company = [tech_company[item] for item in df.tech_company]
df.tech_company.unique()
# Out:
# array([0, 1])

# %%
df.benefits.unique()
benefits= {'Yes':0,'No':1,"Don't know":2}
df.benefits = [benefits[item] for item in df.benefits]
df.benefits.unique()
# Out:
# array([0, 2, 1])

# %%
plt.figure(figsize=(10,5)) #plt is the object of matplot lib and .figure() is used to show or change properties of graphs
sns.heatmap(df.isnull(),cmap='viridis',yticklabels=False,cbar=False)#heatmaps are matrix plots which can visualize data in 2D
plt.show()
#NOw, lets seee the heat map to get the null values.

# %%
# Now, many unwanted columns can be deleted as follows, just add the columns to be dropped, i cant say as to what are not important

# %%
to_drop = ["s.no","Timestamp","state"]
df.drop(columns=to_drop,inplace=True,axis=1)
df.head()
# Out:
#    Age Gender         Country self_employed family_history work_interfere  \
# 0   25      M   United States            No            Yes          Often
# 1   42      M   United States            No            Yes      Sometimes
# 2   34      M   United States            No            Yes          Often
# 3   26      F   United States            No             No      Sometimes
# 4   35      M  United Kingdom            No            Yes      Sometimes
#
#   no_employees remote_work tech_company    benefits  ...    supervisor  \
# 0         6-25         Yes          Yes         Yes  ...           Yes
# 1         6-25         Yes          Yes  Don't know  ...           Yes
# 2      100-500          No          Yes         Yes  ...           Yes
# 3       26-100         Yes          Yes  Don't know  ...            No
# 4          1-5          No          Yes          No  ...  Some of them
#
#   mental_health_interview phys_health_interview mental_vs_physical  \
# 0                   Maybe                 Maybe         Don't know
# 1                      No                 Maybe         Don't know
# 2                   Maybe                 Maybe         Don't know
# 3                   Maybe                 Maybe         Don't know
# 4                      No                 Maybe                Yes
#
#   obs_consequence start_range end_range Day Month  Year
# 0              No           6        25  29     8  2014
# 1              No           6        25  29     8  2014
# 2              No         100       500  29     8  2014
# 3             Yes          26       100  29     8  2014
# 4             Yes           1         5  29     8  2014
#
# [5 rows x 28 columns]

# %%
df.Gender.unique()
Gender= {'M':0,'F':1,'U':2}
df.Gender = [Gender[item] for item in df.Gender]
df.Gender.unique()
# Out:
# array([0, 1, 2])

# %%
#Convcersion of strings to 0,1,2,3 can be done at a shot, please tell and i will try to do.
#This was the first time i did it, so please bhaut galti hoga maaf karna :P

# %%
df.head()
# Out:
#    Age  Gender         Country  self_employed  family_history  work_interfere  \
# 0   25       0   United States              1               0               0
# 1   42       0   United States              1               0               1
# 2   34       0   United States              1               0               0
# 3   26       1   United States              1               1               1
# 4   35       0  United Kingdom              1               0               1
#
#   no_employees  remote_work  tech_company  benefits  ... supervisor  \
# 0         6-25            0             0         0  ...          0
# 1         6-25            0             0         2  ...          0
# 2      100-500            1             0         0  ...          0
# 3       26-100            0             0         2  ...          1
# 4          1-5            1             0         1  ...          2
#
#   mental_health_interview phys_health_interview  mental_vs_physical  \
# 0                       2                     2                   2
# 1                       1                     2                   2
# 2                       2                     2                   2
# 3                       2                     2                   2
# 4                       1                     2                   0
#
#    obs_consequence  start_range end_range  Day  Month  Year
# 0                1            6        25   29      8  2014
# 1                1            6        25   29      8  2014
# 2                1          100       500   29      8  2014
# 3                0           26       100   29      8  2014
# 4                0            1         5   29      8  2014
#
# [5 rows x 28 columns]
